# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.io.wavfile import write
import wave, struct

# wav = wave.open('Good Data - Sandeep no errors/left-middle-right-middle-eyebrow-marina2.wav','r')
wav = wave.open('left-right.wav','r')
print( "Number of channels",wav.getnchannels())
print ( "Sample width",wav.getsampwidth())
print ( "Frame rate.",wav.getframerate)
print ("Number of frames",wav.getnframes())
print ( "parameters:",wav.getparams())


framerate = wav.getframerate()
nframes = wav.getnframes()
        
wav_array = np.array(struct.unpack("<" + "h"*nframes, wav.readframes(nframes)))
test_array = wav_array[110000:140000]



# %matplotlib notebook
plt.plot(test_array)

# classify_event(test_array)
# Out:
# Number of channels 1
# Sample width 2
# Frame rate. <bound method Wave_read.getframerate of <wave.Wave_read object at 0x7ff8f19a42e0>>
# Number of frames 298663
# parameters: _wave_params(nchannels=1, sampwidth=2, framerate=10000, nframes=298663, comptype='NONE', compname='not compressed')
# <img src="data:image/png;base64,..." width="1151.1111416051426">
